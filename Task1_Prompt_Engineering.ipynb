# %%
# !pip install langchain langchain-core langchain-community
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (1.2.15)
# Requirement already satisfied: langchain-core in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (1.2.28)
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (0.7.29)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (9.1.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.3-py3-none-any.whl.metadata (4.8 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain-community)
#   Downloading sqlalchemy-2.0.49-cp314-cp314-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langchain-community) (3.13.5)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.13.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=2.1.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from langchain-community) (2.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.1 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Eng.Shital\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.6.3)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community)
#   Downloading greenlet-3.4.0-cp314-cp314-win_amd64.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------- ----------------------- 1.0/2.5 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 10.0 MB/s  0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.3-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 5.6 MB/s  0:00:00
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading pydantic_settings-2.13.1-py3-none-any.whl (58 kB)
# Downloading sqlalchemy-2.0.49-cp314-cp314-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 10.2 MB/s  0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading greenlet-3.4.0-cp314-cp314-win_amd64.whl (239 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, greenlet, typing-inspect, SQLAlchemy, pydantic-settings, dataclasses-json, langchain-text-splitters, langchain-classic, langchain-community
#
#    ------ ---------------------------------  2/12 [marshmallow]
#    ------------- --------------------------  4/12 [greenlet]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    -------------------- -------------------  6/12 [SQLAlchemy]
#    ----------------------- ----------------  7/12 [pydantic-settings]
#    -------------------------- -------------  8/12 [dataclasses-json]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    --------------------------------- ------ 10/12 [langchain-classic]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ------------------------------------ --- 11/12 [langchain-community]
#    ---------------------------------------- 12/12 [langchain-community]
#
# Successfully installed SQLAlchemy-2.0.49 dataclasses-json-0.6.7 greenlet-3.4.0 httpx-sse-0.4.3 langchain-classic-1.0.3 langchain-community-0.4.1 langchain-text-splitters-1.1.1 marshmallow-3.26.2 mypy-extensions-1.1.0 pydantic-settings-2.13.1 python-dotenv-1.2.2 typing-inspect-0.9.0
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# from langchain_core.prompts import PromptTemplate
# from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# #Task 1: Replace Hardcoded Prompts

# %%
template_1 = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

# Example
print(template_1.format(topic="Artificial Intelligence"))
# Out:
# Explain Artificial Intelligence in simple terms for beginners

# %% [markdown]
# #Task 2: Multi-Input Prompt System

# %%
multi_input_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

# Test Cases
print(multi_input_template.format(topic="AI", audience="beginners", tone="friendly"))
print(multi_input_template.format(topic="Python", audience="kids", tone="fun"))
print(multi_input_template.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %% [markdown]
# #Task 3: Prompt Variations Engine

# %%
# Teaching Template
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

# Interview Template
interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

# Storytelling Template
story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 interview questions about Machine Learning
# Explain Machine Learning as a story

# %% [markdown]
# Task 4: ChatPromptTemplate System

# %%
def get_chat_prompt(role, topic):
    
    if role == "teacher":
        system_message = "You are a helpful teacher who explains concepts clearly."
    elif role == "interviewer":
        system_message = "You are an interviewer who asks challenging questions."
    elif role == "motivator":
        system_message = "You are a motivator who inspires learners."
    else:
        system_message = "You are a helpful assistant."

    chat_template = ChatPromptTemplate.from_messages([
        ("system", system_message),
        ("user", "Tell me about {topic}")
    ])

    return chat_template.format_messages(topic=topic)


# Example
messages = get_chat_prompt("teacher", "Neural Networks")
print(messages)
# Out:
# [SystemMessage(content='You are a helpful teacher who explains concepts clearly.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Tell me about Neural Networks', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# #Task 5: Input Validation Layer

# %%
def validate_inputs(audience, tone):
    
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]

    # Validation
    if audience not in valid_audience:
        print("Invalid audience! Setting default = beginner")
        audience = "beginner"

    if tone not in valid_tone:
        print("Invalid tone! Setting default = formal")
        tone = "formal"

    return audience, tone


# Example
audience, tone = validate_inputs("kids", "cool")
print(audience, tone)
# Out:
# Invalid audience! Setting default = beginner
# Invalid tone! Setting default = formal
# beginner formal

# %% [markdown]
# #Task 6: Prompt Generator App

# %%
def generate_prompt(topic, audience, tone, style):

    # Validate inputs
    audience, tone = validate_inputs(audience, tone)

    # Style Templates
    if style == "teaching":
        template = "Explain {topic} for {audience} in a {tone} tone step by step"
    elif style == "interview":
        template = "Ask interview questions about {topic} for {audience} in a {tone} tone"
    elif style == "storytelling":
        template = "Explain {topic} for {audience} in a {tone} storytelling style"
    else:
        template = "Explain {topic} for {audience} in a {tone} tone"

    prompt = PromptTemplate(
        input_variables=["topic", "audience", "tone"],
        template=template
    )

    return prompt.format(topic=topic, audience=audience, tone=tone)


# Example
print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
# Out:
# Explain Neural Networks for beginner in a fun storytelling style

# %% [markdown]
# #Task 7: Template Reusability Test

# %%
reusable_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

# 5 Different Inputs
print(reusable_template.format(topic="AI", audience="beginner", tone="formal"))
print(reusable_template.format(topic="Python", audience="expert", tone="casual"))
print(reusable_template.format(topic="Blockchain", audience="intermediate", tone="fun"))
print(reusable_template.format(topic="Cloud Computing", audience="beginner", tone="casual"))
print(reusable_template.format(topic="Cyber Security", audience="expert", tone="formal"))
# Out:
# Explain AI for beginner in a formal tone
# Explain Python for expert in a casual tone
# Explain Blockchain for intermediate in a fun tone
# Explain Cloud Computing for beginner in a casual tone
# Explain Cyber Security for expert in a formal tone
